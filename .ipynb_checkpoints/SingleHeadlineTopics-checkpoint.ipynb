# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pymongo import MongoClient

from collections import Counter
from collections import defaultdict

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans,KMeans,DBSCAN,AgglomerativeClustering
from sklearn.feature_selection import SelectKBest

from nltk.corpus import stopwords
from nltk import word_tokenize

from gensim import corpora, models, similarities

# %% [markdown]
# ##Load the data from MongoDB

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.Fletcher_db
collection = db.presidential_articles

# %%
articles = []
cursor = collection.find()
for c in cursor:
    articles.append(c)

# %% [markdown]
# ##Create a list of headlines
# Filter out headlines of a certain time-specific format

# %%
stop_phrases = ['news summary','news analysis','business digest','early word','inside the times','breakfast menu',
                'quotations day','quotations of the day','best sellers','evening briefing','monday briefing','tuesday briefing',
                'wednesday briefing','thursday briefing','friday briefing','saturday briefing','sunday briefing',
                'morning skim']

headlines=[]
ym_list = []
for article in articles:
    headline = article['headline']['main'].lower()
    include = True
    for phrase in stop_phrases:
        if phrase in headline:
            include = False
            break
    if include:
        headlines.append(headline)
        ym_list.append((article['Year'],article['Month']))

# %% [markdown]
# ##Create topics from the headlines

# %%
stop = stopwords.words('english')
pres_names = ['obama','bush','clinton','bush','reagan']
dates = [str(year) for year in range(1980,2015)]

stop_all = stop + pres_names + dates

# %%
tokens = [word_tokenize(headline) for headline in headlines]
tokens = [[word for word in headline if word not in stop_all] for headline in tokens]

dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(headline) for headline in tokens]

tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
lda = models.ldamodel.LdaModel(corpus_tfidf, id2word=dictionary, num_topics=100,passes=30)
corpus_lda = lda[corpus_tfidf]

# %%
for i,a in enumerate(lda.show_topics(num_topics = 40)):
    print i
    print a
    print
# Out:
# 0
# 0.100*time + 0.057*agency + 0.044*) + 0.044*( + 0.027*banks + 0.018*rich + 0.014*stands + 0.013*, + 0.012*passed + 0.012*demand
#
# 1
# 0.118*political + 0.055*go + 0.055*| + 0.032*statement + 0.028*leaves + 0.027*central + 0.027*land + 0.019*embassy + 0.016*guantánamo + 0.013*led
#
# 2
# 0.042*farm + 0.040*governor + 0.028*stage + 0.025*found + 0.023*campaigns + 0.022*terms + 0.020*risks + 0.019*virginia + 0.019*avoid + 0.018*moving
#
# 3
# 0.101*talk + 0.041*reported + 0.039*victory + 0.033*; + 0.027*storm + 0.023*mixed + 0.022*sales + 0.020*united + 0.019*disaster + 0.018*stem
#
# 4
# 0.061*west + 0.060*taxes + 0.054*abroad + 0.037*question + 0.031*fears + 0.024*giuliani + 0.019*fraud + 0.017*torture + 0.017*papers + 0.016*danger
#
# 5
# 0.074*federal + 0.067*tv + 0.055*judge + 0.053*nicaragua + 0.044*keep + 0.043*road + 0.032*cheney + 0.027*hinckley + 0.024*ads + 0.015*style
#
# 6
# 0.086*leaders + 0.046*seeking + 0.045*message + 0.039*strike + 0.034*drive + 0.032*hold + 0.025*hostages + 0.024*pledge + 0.023*loan + 0.018*sea
#
# 7
# 0.059*push + 0.057*could + 0.054*senator + 0.051*show + 0.042*step + 0.032*costs + 0.031*order + 0.022*prosecutor + 0.020*citing + 0.020*reduce
#
# 8
# 0.048*look + 0.034*cabinet + 0.030*term + 0.026*ways + 0.018*closer + 0.018*stock + 0.018*st. + 0.017*comments + 0.016*; + 0.015*kills
#
# 9
# 0.132*debate + 0.059*calendar + 0.044*iraqi + 0.028*relief + 0.026*seat + 0.023*lives + 0.022*problems + 0.021*thursday + 0.020*slow + 0.019*media
#
# 10
# 0.079*votes + 0.050*pay + 0.050*trip + 0.043*lines + 0.040*give + 0.031*sets + 0.028*laugh + 0.026*... + 0.026*6 + 0.025*gap
#
# 11
# 0.104*world + 0.062*quiz + 0.057*calls + 0.056*gulf + 0.054*moscow + 0.052*rules + 0.046*american + 0.034*bid + 0.029*mind + 0.019*search
#
# 12
# 0.063*shultz + 0.037*general + 0.029*join + 0.029*nomination + 0.025*bills + 0.025*book + 0.024*ruling + 0.023*bonn + 0.023*goal + 0.016*tokyo
#
# 13
# 0.057*says + 0.043*lead + 0.043*california + 0.040*goes + 0.037*near + 0.025*bomb + 0.022*page + 0.019*ca + 0.016*qaeda + 0.016*prayer
#
# 14
# 0.077*deficit + 0.054*mondale + 0.032*texas + 0.029*stop + 0.027*family + 0.023*growth + 0.021*; + 0.020*coast + 0.019*success + 0.018*leaving
#
# 15
# 0.089*economic + 0.071*said + 0.064*summit + 0.056*aides + 0.028*bosnia + 0.027*cuomo + 0.024*private + 0.023*find + 0.021*drop + 0.018*divided
#
# 16
# 0.071*party + 0.064*backs + 0.048*focus + 0.041*free + 0.040*gives + 0.038*wo + 0.030*n't + 0.025*list + 0.025*bar + 0.021*dies
#
# 17
# 0.177*congress + 0.047*head + 0.038*dispute + 0.037*compromise + 0.034*afghanistan + 0.030*criticism + 0.029*essay + 0.027*break + 0.023*returns + 0.021*geneva
#
# 18
# 0.113*home + 0.058*tells + 0.042*begins + 0.037*gay + 0.035*try + 0.030*marriage + 0.025*praises + 0.015*wife + 0.015*demands + 0.014*events
#
# 19
# 0.115*tax + 0.053*romney + 0.052*top + 0.049*approves + 0.046*poll + 0.038*faces + 0.027*march + 0.026*foes + 0.023*made + 0.022*getting
#
# 20
# 0.059*high + 0.049*women + 0.046*east + 0.040*dollar + 0.035*rule + 0.032*turns + 0.030*middle + 0.019*george + 0.014*caution + 0.013*f.c.c
#
# 21
# 0.072*candidates + 0.064*key + 0.057*years + 0.037*schools + 0.036*arts + 0.032*puts + 0.022*challenges + 0.021*given + 0.019*regan + 0.016*sending
#
# 22
# 0.150*inside + 0.065*u.s + 0.047*missile + 0.040*make + 0.031*. + 0.029*meese + 0.028*beirut + 0.025*russian + 0.024*proposes + 0.019*weinberger
#
# 23
# 0.129*health + 0.079*care + 0.058*act + 0.038*plan + 0.037*! + 0.032*looks + 0.030*recovery + 0.023*putin + 0.021*different + 0.017*works
#
# 24
# 0.085*saturday + 0.042*lawmakers + 0.039*ideas + 0.038*word + 0.031*jobless + 0.026*parley + 0.022*announces + 0.021*three + 0.021*medicaid + 0.018*rice
#
# 25
# 0.060*take + 0.047*mexico + 0.035*5 + 0.031*street + 0.029*review + 0.029*wall + 0.027*border + 0.021*cold + 0.021*art + 0.019*latest
#
# 26
# 0.094*plans + 0.047*dole + 0.038*major + 0.031*tests + 0.027*unit + 0.025*asserts + 0.022*shifts + 0.022*saudi + 0.021*among + 0.020*premier
#
# 27
# 0.082*money + 0.032*raises + 0.029*savings + 0.029*fund + 0.021*dow + 0.021*blair + 0.019*outlook + 0.018*morning + 0.017*access + 0.016*love
#
# 28
# 0.114*iran + 0.073*power + 0.058*questions + 0.042*dept + 0.037*run + 0.026*stay + 0.024*violence + 0.018*'the + 0.017*. + 0.016*falls
#
# 29
# 0.078*deal + 0.077*issue + 0.067*gorbachev + 0.060*national + 0.049*scene + 0.043*education + 0.027*progress + 0.027*service + 0.026*like + 0.024*system
#
# 30
# 0.083*still + 0.051*attacks + 0.049*allies + 0.029*dead + 0.026*point + 0.026*appeal + 0.023*reach + 0.019*8 + 0.019*hits + 0.019*volcker
#
# 31
# 0.072*one + 0.064*press + 0.058*presidential + 0.045*assails + 0.036*behind + 0.032*final + 0.025*intelligence + 0.023*board + 0.022*draft + 0.021*hearing
#
# 32
# 0.178*campaign + 0.050*good + 0.044*another + 0.042*view + 0.033*death + 0.028*jackson + 0.027*: + 0.025*ground + 0.017*environment + 0.013*advances
#
# 33
# 0.152*war + 0.075*rights + 0.052*mr. + 0.044*official + 0.040*c.i.a + 0.035*little + 0.030*. + 0.027*civil + 0.025*without + 0.024*raise
#
# 34
# 0.103*nation + 0.067*south + 0.042*bank + 0.037*start + 0.036*agenda + 0.031*rally + 0.031*bad + 0.028*1 + 0.025*held + 0.023*7
#
# 35
# 0.079*say + 0.062*bill + 0.040*veto + 0.037*old + 0.036*passes + 0.026*critics + 0.025*policies + 0.024*israelis + 0.020*fiscal + 0.020*gingrich
#
# 36
# 0.062*first + 0.049*study + 0.035*gas + 0.031*chinese + 0.024*' + 0.022*chairman + 0.020*judges + 0.017*religion + 0.017*student + 0.017*loans
#
# 37
# 0.071*new + 0.065*york + 0.059*rise + 0.050*gains + 0.046*signs + 0.045*sanctions + 0.032*summary + 0.029*watch + 0.023*ad + 0.021*friday
#
# 38
# 0.057*pentagon + 0.039*children + 0.036*journal + 0.031*ease + 0.030*treasury + 0.030*charges + 0.025*picks + 0.022*pick + 0.020*anger + 0.020*island
#
# 39
# 0.081*seeks + 0.057*work + 0.047*terror + 0.032*team + 0.026*rises + 0.026*response + 0.025*police + 0.023*agreement + 0.017*kosovo + 0.017*unlikely

# %%
# !say done
# !osascript -e 'display notification "Lorem ipsum dolor sit amet" with title "Title"'

# %% [markdown]
# ##Split articles into year/month segments
# Concatenate the headlines into one string

# %%
year_months = defaultdict(list)
for a in articles:
    year_months[(a['Year'],a['Month'])].append(a)

# %%
ym_headlines = defaultdict(str)
for key in year_months.keys():
    for article in year_months[key]:
        ym_headlines[key]+=article['headline']['main']+' '

# %%
ym_values = []
ym_keys = ym_headlines.keys()
for key in ym_keys:
    ym_values.append(ym_headlines[key])

ym_tokens = [word_tokenize(headlines_string) for headlines_string in ym_values]
ym_tokens = [[word for word in headlines_tokens if word not in stop_all] for headlines_tokens in ym_tokens]

# %% [markdown]
# ##Check topic probabilities on each year/month segments

# %%
ym_corpus = [dictionary.doc2bow(doc) for doc in ym_tokens]
ym_tfidf = models.TfidfModel(ym_corpus)
ym_corpus_tfidf = ym_tfidf[ym_corpus]
ym_corpus_lda = lda[ym_corpus_tfidf]

# %%
ym_lda_probs=list(ym_corpus_lda)

# %% [markdown]
# ##Map each topic to year/month and topic probability

# %%
topics = defaultdict(list)
for ym,data in zip(ym_keys,ym_lda_probs):
    for d in data:
        topics[d[0]].append((ym,d[1]))

for topic in topics.keys():
    topic_yms = [value[0] for value in topics[topic]]
    for ym in ym_keys:
        if ym not in topic_yms:
            topics[topic].append((ym,0))
            
for t in topics.keys():
    topics[t]=sorted(topics[t])

# %%
# y_values = [value[1] for value in topics[0]]
# plt.plot(range(len(topics[0])),y_values)
fig,ax=plt.subplots(figsize=(15,7))
y_values = [value[1] for value in topics[4]]

average_vals=[y_values[0]]
for i in range(1,len(y_values)-1):
    previous_val = y_values[i-1]
    current_val = y_values[i]
    next_val = y_values[i+1]
    average = (previous_val+current_val+next_val)/3.0
    average_vals.append(average)
average_vals.append(y_values[-1])

#ax.plot(range(len(topics[0])),y_values,color='r')
ax.plot(range(len(topics[0])),average_vals,color='r')


ticks = [b[0] for i,b in enumerate(sorted(ym_keys)) if i%12==0]
locs = [b for b in range(len(y_values)) if b%12==0]
_=ax.set_xticks(locs)
_=ax.set_xticklabels(ticks,rotation='vertical')

# %% [markdown]
# ##Assign each headline to a topic
# ##Keep track the number of each topic for each month

# %%
import operator
lda_probs=list(corpus_lda)

# %%
lda_probs[3484]
# Out:
# []

# %%
most_common = defaultdict(str)
ym_clusters = defaultdict(list)
i=0
for h,prob in zip(headlines,lda_probs):
    if len(prob)!=0:
        top = sorted(prob,key=operator.itemgetter(1),reverse=True)[0][0]
        most_common[top] += h + ' '
        ym_clusters[ym_list[i]].append(top)
    i+=1

# %% [markdown]
# ##Find the top kws for each topic

# %%
vectorizer = TfidfVectorizer(stop_words=stop_all, ngram_range=(1,2),max_df=0.8,max_features=5000)
headlines_vectors = vectorizer.fit_transform(most_common.values())

# %%
kws = defaultdict(list)
for t in most_common.keys():
    indices = headlines_vectors[t].indices
    data = headlines_vectors[t].data
    for kw_index,tfidf in zip(indices,data):
        kws[t].append((tfidf,vectorizer.get_feature_names()[kw_index]))
    kws[t]=sorted(kws[t],reverse=True)

# %%
for t in kws.keys():
    print t,[kw[1] for kw in kws[t][:20]]
# Out:
# 99 [u'week ahead', u'next week', u'necessary', u'barack', u'cure', u'dream', u'timing', u'detention', u'got', u'heartland', u'week business', u'ecuador', u'inaction', u'economic reports', u'tech', u'reviewing', u'spend', u'hurry', u'prisons', u'daughter']

# %%
##For 1 month average (Otherwise same functionality as below cell)


ym_headline_probas = defaultdict(dict)

for ym in ym_clusters.keys():
    curr_headline_probas = defaultdict(float)
    
    topic_list = ym_clusters[ym]
    num_headlines = len(topic_list)
    
    for t in topic_list:
        curr_headline_probas[t]+=1
    
    for t in curr_headline_probas.keys():
        curr_headline_probas[t]=float(curr_headline_probas[t])/(num_headlines)
    
    ym_headline_probas[ym] = curr_headline_probas

# %%
# ##For 3 month average (Otherwise same functionality as above cell)

# ym_headline_probas = defaultdict(dict)

# prev_headline_count = defaultdict(float)
# prev_topic_list = ym_clusters[ym_keys[0]]
# prev_num_headlines = len(prev_topic_list)

# for t in prev_topic_list:
#     prev_headline_count[t]+=1

# for i in range(1,len(ym_keys)-1):
#     average_probas={}
#     next_headline_count = dict.fromkeys(range(100))
#     for d in next_headline_count.keys():
#         next_headline_count[d]=0
    
#     next_topic_list=ym_clusters[ym_keys[i+1]]
#     next_num_headlines=len(next_topic_list)
    
#     for t in next_topic_list:
#         next_headline_count[t]+=1
    
#     for t in next_headline_count.keys():
#         total_count=prev_headline_count[t]+curr_headline_count[t]+next_headline_count[t]
#         total_num_headlines=prev_num_headlines+curr_num_headlines+next_num_headlines
#         average_probas[t]=float(total_count)/total_num_headlines
#     ym_headline_probas[ym_keys[i]]=average_probas
    
    
#     prev_headline_count=curr_headline_count
#     curr_headline_count=next_headline_count
    
#     prev_num_headlines=curr_num_headlines
#     curr_num_headlines=next_num_headlines

# %%
ts = [4]
fig,ax = plt.subplots(figsize=(20,3))

for t in ts:
    vals = []
    for i,ym in enumerate(sorted(ym_headline_probas)):
        c_ym = sorted(ym_keys)[i]
        p_ym = sorted(ym_keys)[i-1]
        n_ym = sorted(ym_keys)[(i+1)%len(ym_headline_probas)]
        val = ym_headline_probas[c_ym][t]+ym_headline_probas[p_ym][t]+ym_headline_probas[n_ym][t]
        val = val/3
        vals.append(val)
    
    ax.plot(range(len(vals)),vals)


ticks = [b[0] for i,b in enumerate(sorted(ym_keys)) if i%12==0]
locs = [b for b in range(len(y_values)) if b%12==0]
_=ax.set_xticks(locs)
_=ax.set_xticklabels(ticks,rotation='vertical')

# %%
t = 56
vals = []
for ym in sorted(ym_headline_probas):
    val = ym_headline_probas[ym][t]
    vals.append(val)

    
fig,ax = plt.subplots(figsize=(20,5))
ax.plot(range(len(vals)),vals)


ticks = [b[0] for i,b in enumerate(sorted(ym_keys)) if i%12==0]
locs = [b for b in range(len(y_values)) if b%12==0]
_=ax.set_xticks(locs)
_=ax.set_xticklabels(ticks,rotation='vertical')
